# %%
# !pip install Pillow

# %%
from PIL import image 

infile = "FOTO SHAFIRA.jpeg"

im = immage.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c4c904d0c99c> in <module>
# ----> 1 from PIL import image
#       2
#       3 infile = "FOTO SHAFIRA.jpeg"
#       4
#       5 im = immage.open(infile)
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\bri\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
from PIL import image 

infile = "FOTO SHAFIRA.jpeg"

im = image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-da0fd8b8ea8e> in <module>
# ----> 1 from PIL import image
#       2
#       3 infile = "FOTO SHAFIRA.jpeg"
#       4
#       5 im = image.open(infile)
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\bri\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
from PIL import image 

infile = "FOTO SHAFIRA.jpeg"

im = image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-da0fd8b8ea8e> in <module>
# ----> 1 from PIL import image
#       2
#       3 infile = "FOTO SHAFIRA.jpeg"
#       4
#       5 im = image.open(infile)
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\bri\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
from PIL import image 

infile = "Brought to you by salt (1).png"

im = Image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-6b9aed8e99a7> in <module>
# ----> 1 from PIL import image
#       2
#       3 infile = "Brought to you by salt (1).png"
#       4
#       5 im = Image.open(infile)
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\bri\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
from PIL import Image 

infile = "Brought to you by salt (1).png"

im = Image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ff5fc4ef508c> in <module>
#       3 infile = "Brought to you by salt (1).png"
#       4
# ----> 5 im = Image.open(infile)
#       6 display(im)
#       7
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Brought to you by salt (1).png'

# %%
from PIL import Image 

infile = "Brought to you by salt (1).png"

im = Image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# ---------------------------------------------------------------------------
# DecompressionBombError                    Traceback (most recent call last)
# <ipython-input-12-ff5fc4ef508c> in <module>
#       3 infile = "Brought to you by salt (1).png"
#       4
# ----> 5 im = Image.open(infile)
#       6 display(im)
#       7
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2951         return None
#    2952
# -> 2953     im = _open_core(fp, filename, prefix, formats)
#    2954
#    2955     if im is None:
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _open_core(fp, filename, prefix, formats)
#    2938                     fp.seek(0)
#    2939                     im = factory(fp, filename)
# -> 2940                     _decompression_bomb_check(im.size)
#    2941                     return im
#    2942             except (SyntaxError, IndexError, TypeError, struct.error):
#
# ...

# %%
from PIL import Image 

infile = "FOTO SHAFIRA.jpeg"

im = Image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1280 at 0x2CE57FAF9A0>
# FOTO SHAFIRA.jpeg JPEG 1280x1280 RGB
